# %% [markdown]
# ## waste management using cnn model

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing necessary libraries
import numpy as np
import pandas as pd
print(pd.__version__)  # This should print the installed version of pandas

import pandas as pd
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')
# Out:
# 2.2.3

# %%
train_path ="DATASET/TRAIN"
test_path ="DATASET/TEST"

# %%
#importing librariies
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout,BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.utils import plot_model

# %%
#visualization
import cv2
print(cv2.__version__)
from glob import glob
from cv2 import cvtColor
x_data=[]
y_data=[]
for category in glob(train_path+'/*'):
  for file in tqdm(glob(category+'/*')):
    img_array = cv2.imread(file)
    img_array = cvtColor(img_array , cv2.COLOR_BGR2RGB)
    x_data.append(img_array)
    y_data.append(category.split('/')[-1])
data = pd.DataFrame({'image':x_data, 'label':y_data})
# Out:
# 4.11.0
# ...
# 100%|██████████| 9999/9999 [00:07<00:00, 1398.05it/s]

# %%
data.shape
# Out:
# (22564, 2)

# %%
colors=['#a0d157','#c48bb8']
plt.pie(data.label.value_counts(), labels =['organic ', 'recyclable'] ,autopct='%0.2f' )
plt.show()

# %%
from matplotlib.patches import Wedge

# Define the data
label_counts = [120, 80]  # Example counts for 'organic' and 'recyclable'
labels = ['organic', 'recyclable']
colors = ['#a0d157', '#c48bb8']

# Create the pie chart and extract the wedges
wedges = plt.pie(label_counts, labels=labels, colors=colors, autopct='%0.2f%%')[0]

# Apply patterns to each wedge
hatches = ['/', '\\']
for wedge, hatch in zip(wedges, hatches):
    wedge.set_hatch(hatch)

plt.title("Pie Chart with Patterns")
plt.show()
